# %% [markdown]
# 'bin laden', 'al qaeda', 'twin towers', 'world trade center', 'tower', 'attack', 'hijack', 'firefighter', 'plane', 'terrorism', 'afghanistan', 'jihad', 'islam'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/ProgettiDataScience-SAD/1 ANNO 2 SEMESTRE/DATA SEMANTICS/Progetto/Newspaper')

# %%
BASE_PATH = '/content/drive/MyDrive/ProgettiDataScience-SAD/1 ANNO 2 SEMESTRE/DATA SEMANTICS/Progetto/Newspaper/'


with open(BASE_PATH + 'text_news_nne/text_news_1996.txt') as read_file1:
  sentences1996 = read_file1.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_1997.txt') as read_file2:
  sentences1997 = read_file2.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_1998.txt') as read_file3:
  sentences1998 = read_file3.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_1999.txt') as read_file4:
  sentences1999 = read_file4.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2000.txt') as read_file5:
  sentences2000 = read_file5.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2001.txt') as read_file1:
  sentences2001 = read_file1.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2002.txt') as read_file2:
  sentences2002 = read_file2.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2003.txt') as read_file3:
  sentences2003 = read_file3.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2004.txt') as read_file4:
  sentences2004 = read_file4.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2005.txt') as read_file5:
  sentences2005 = read_file5.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2006.txt') as read_file5:
  sentences2006 = read_file5.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2007.txt') as read_file5:
  sentences2007 = read_file5.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2008.txt') as read_file5:
  sentences2008 = read_file5.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2009.txt') as read_file5:
  sentences2009 = read_file5.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2010.txt') as read_file5:
  sentences2010 = read_file5.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2011.txt') as read_file5:
  sentences2011 = read_file5.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2012.txt') as read_file5:
  sentences2012 = read_file5.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2013.txt') as read_file5:
  sentences2013 = read_file5.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2014.txt') as read_file5:
  sentences2014 = read_file5.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2015.txt') as read_file5:
  sentences2015 = read_file5.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2016.txt') as read_file5:
  sentences2016 = read_file5.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2017.txt') as read_file5:
  sentences2017 = read_file5.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2018.txt') as read_file5:
  sentences2018 = read_file5.readlines()
with open(BASE_PATH + 'text_news_nne/text_news_2019.txt') as read_file5:
  sentences2019 = read_file5.readlines()

# %% [markdown]
# # 1996

# %%
count_binLanden1996 = 0

for s in sentences1996:
  count_binLanden1996 += s.lower().count('bin laden')

print(count_binLanden1996)
# Out:
# 1

# %%
count_alQaeda1996 = 0

for s in sentences1996:
  count_alQaeda1996 += s.lower().count('al qaeda')

print(count_alQaeda1996)
# Out:
# 0

# %%
count_twinTowers1996 = 0

for s in sentences1996:
  count_twinTowers1996 += s.lower().count('twin towers')

print(count_twinTowers1996)
# Out:
# 2

# %%
count_worldTradeCenter1996 = 0

for s in sentences1996:
  count_worldTradeCenter1996 += s.lower().count('world trade center')

print(count_worldTradeCenter1996)
# Out:
# 16

# %%
count_tower1996 = 0

for s in sentences1996:
  count_tower1996 += s.lower().count('tower')

print(count_tower1996)
# Out:
# 187

# %%
count_attack1996 = 0

for s in sentences1996:
  count_attack1996 += s.lower().count('attack')

print(count_attack1996)
# Out:
# 717

# %%
count_hijack1996 = 0

for s in sentences1996:
  count_hijack1996 += s.lower().count('hijack')

print(count_hijack1996)
# Out:
# 19

# %%
count_plane1996 = 0

for s in sentences1996:
  count_plane1996 += s.lower().count('plane')

print(count_plane1996)
# Out:
# 762

# %%
count_terrorism1996 = 0

for s in sentences1996:
  count_terrorism1996 += s.lower().count('terrorism')

print(count_terrorism1996)
# Out:
# 120

# %%
count_afghanistan1996 = 0

for s in sentences1996:
  count_afghanistan1996 += s.lower().count('afghanistan')

print(count_afghanistan1996)
# Out:
# 56

# %%
count_jihad1996 = 0

for s in sentences1996:
  count_jihad1996 += s.lower().count('jihad')

print(count_jihad1996)
# Out:
# 4

# %%
count_islam1996 = 0

for s in sentences1996:
  count_islam1996 += s.lower().count('islam')

print(count_islam1996)
# Out:
# 196

# %% [markdown]
# # 1997

# %%
count_binLanden1997 = 0

for s in sentences1997:
  count_binLanden1997 += s.lower().count('bin laden')

print(count_binLanden1997)
# Out:
# 0

# %%
count_alQaeda1997 = 0

for s in sentences1997:
  count_alQaeda1997 += s.lower().count('al qaeda')

print(count_alQaeda1997)
# Out:
# 0

# %%
count_twinTowers1997 = 0

for s in sentences1997:
  count_twinTowers1997 += s.lower().count('twin towers')

print(count_twinTowers1997)
# Out:
# 4

# %%
count_worldTradeCenter1997 = 0

for s in sentences1997:
  count_worldTradeCenter1997 += s.lower().count('world trade center')

print(count_worldTradeCenter1997)
# Out:
# 11

# %%
count_tower1997 = 0

for s in sentences1997:
  count_tower1997 += s.lower().count('tower')

print(count_tower1997)
# Out:
# 283

# %%
count_attack1997 = 0

for s in sentences1997:
  count_attack1997 += s.lower().count('attack')

print(count_attack1997)
# Out:
# 558

# %%
count_hijack1997 = 0

for s in sentences1997:
  count_hijack1997 += s.lower().count('hijack')

print(count_hijack1997)
# Out:
# 19

# %%
count_plane1997 = 0

for s in sentences1997:
  count_plane1997 += s.lower().count('plane')

print(count_plane1997)
# Out:
# 551

# %%
count_terrorism1997 = 0

for s in sentences1997:
  count_terrorism1997 += s.lower().count('terrorism')

print(count_terrorism1997)
# Out:
# 53

# %%
count_afghanistan1997 = 0

for s in sentences1997:
  count_afghanistan1997 += s.lower().count('afghanistan')

print(count_afghanistan1997)
# Out:
# 18

# %%
count_jihad1997 = 0

for s in sentences1997:
  count_jihad1997 += s.lower().count('jihad')

print(count_jihad1997)
# Out:
# 6

# %%
count_islam1997 = 0

for s in sentences1997:
  count_islam1997 += s.lower().count('islam')

print(count_islam1997)
# Out:
# 158

# %% [markdown]
# # 1998

# %%
count_binLanden1998 = 0

for s in sentences1998:
  count_binLanden1998 += s.lower().count('bin laden')

print(count_binLanden1998)
# Out:
# 20

# %%
count_alQaeda1998 = 0

for s in sentences1998:
  count_alQaeda1998 += s.lower().count('al qaeda')

print(count_alQaeda1998)
# Out:
# 0

# %%
count_twinTowers1998 = 0

for s in sentences1998:
  count_twinTowers1998 += s.lower().count('twin towers')

print(count_twinTowers1998)
# Out:
# 6

# %%
count_worldTradeCenter1998 = 0

for s in sentences1998:
  count_worldTradeCenter1998 += s.lower().count('world trade center')

print(count_worldTradeCenter1998)
# Out:
# 8

# %%
count_tower1998 = 0

for s in sentences1998:
  count_tower1998 += s.lower().count('tower')

print(count_tower1998)
# Out:
# 241

# %%
count_attack1998 = 0

for s in sentences1998:
  count_attack1998 += s.lower().count('attack')

print(count_attack1998)
# Out:
# 648

# %%
count_hijack1998 = 0

for s in sentences1998:
  count_hijack1998 += s.lower().count('hijack')

print(count_hijack1998)
# Out:
# 8

# %%
count_plane1998 = 0

for s in sentences1998:
  count_plane1998 += s.lower().count('plane')

print(count_plane1998)
# Out:
# 459

# %%
count_terrorism1998 = 0

for s in sentences1998:
  count_terrorism1998 += s.lower().count('terrorism')

print(count_terrorism1998)
# Out:
# 53

# %%
count_afghanistan1998 = 0

for s in sentences1998:
  count_afghanistan1998 += s.lower().count('afghanistan')

print(count_afghanistan1998)
# Out:
# 54

# %%
count_jihad1998 = 0

for s in sentences1998:
  count_jihad1998 += s.lower().count('jihad')

print(count_jihad1998)
# Out:
# 3

# %%
count_islam1998 = 0

for s in sentences1998:
  count_islam1998 += s.lower().count('islam')

print(count_islam1998)
# Out:
# 180

# %% [markdown]
# # 1999

# %%
count_binLanden1999 = 0

for s in sentences1999:
  count_binLanden1999 += s.lower().count('bin laden')

print(count_binLanden1999)
# Out:
# 7

# %%
count_alQaeda1999 = 0

for s in sentences1999:
  count_alQaeda1999 += s.lower().count('al qaeda')

print(count_alQaeda1999)
# Out:
# 0

# %%
count_twinTowers1999 = 0

for s in sentences1999:
  count_twinTowers1999 += s.lower().count('twin towers')

print(count_twinTowers1999)
# Out:
# 2

# %%
count_worldTradeCenter1999 = 0

for s in sentences1999:
  count_worldTradeCenter1999 += s.lower().count('world trade center')

print(count_worldTradeCenter1999)
# Out:
# 3

# %%
count_tower1999 = 0

for s in sentences1999:
  count_tower1999 += s.lower().count('tower')

print(count_tower1999)
# Out:
# 259

# %%
count_attack1999 = 0

for s in sentences1999:
  count_attack1999 += s.lower().count('attack')

print(count_attack1999)
# Out:
# 641

# %%
count_hijack1999 = 0

for s in sentences1999:
  count_hijack1999 += s.lower().count('hijack')

print(count_hijack1999)
# Out:
# 16

# %%
count_plane1999 = 0

for s in sentences1999:
  count_plane1999 += s.lower().count('plane')

print(count_plane1999)
# Out:
# 735

# %%
count_terrorism1999 = 0

for s in sentences1999:
  count_terrorism1999 += s.lower().count('terrorism')

print(count_terrorism1999)
# Out:
# 35

# %%
count_afghanistan1999 = 0

for s in sentences1999:
  count_afghanistan1999 += s.lower().count('afghanistan')

print(count_afghanistan1999)
# Out:
# 15

# %%
count_jihad1999 = 0

for s in sentences1999:
  count_jihad1999 += s.lower().count('jihad')

print(count_jihad1999)
# Out:
# 4

# %%
count_islam1999 = 0

for s in sentences1999:
  count_islam1999 += s.lower().count('islam')

print(count_islam1999)
# Out:
# 105

# %% [markdown]
# # 2000

# %%
count_binLanden2000 = 0

for s in sentences2000:
  count_binLanden2000 += s.lower().count('bin laden')

print(count_binLanden2000)
# Out:
# 46

# %%
count_alQaeda2000 = 0

for s in sentences2000:
  count_alQaeda2000 += s.lower().count('al qaeda')

print(count_alQaeda2000)
# Out:
# 0

# %%
count_twinTowers2000 = 0

for s in sentences2000:
  count_twinTowers2000 += s.lower().count('twin towers')

print(count_twinTowers2000)
# Out:
# 2

# %%
count_worldTradeCenter2000 = 0

for s in sentences2000:
  count_worldTradeCenter2000 += s.lower().count('world trade center')

print(count_worldTradeCenter2000)
# Out:
# 5

# %%
count_tower2000 = 0

for s in sentences2000:
  count_tower2000 += s.lower().count('tower')

print(count_tower2000)
# Out:
# 205

# %%
count_attack2000 = 0

for s in sentences2000:
  count_attack2000 += s.lower().count('attack')

print(count_attack2000)
# Out:
# 664

# %%
count_hijack2000 = 0

for s in sentences2000:
  count_hijack2000 += s.lower().count('hijack')

print(count_hijack2000)
# Out:
# 44

# %%
count_plane2000 = 0

for s in sentences2000:
  count_plane2000 += s.lower().count('plane')

print(count_plane2000)
# Out:
# 547

# %%
count_terrorism2000 = 0

for s in sentences2000:
  count_terrorism2000 += s.lower().count('terrorism')

print(count_terrorism2000)
# Out:
# 42

# %%
count_afghanistan2000 = 0

for s in sentences2000:
  count_afghanistan2000 += s.lower().count('afghanistan')

print(count_afghanistan2000)
# Out:
# 31

# %%
count_jihad2000 = 0

for s in sentences2000:
  count_jihad2000 += s.lower().count('jihad')

print(count_jihad2000)
# Out:
# 33

# %%
count_islam2000 = 0

for s in sentences2000:
  count_islam2000 += s.lower().count('islam')

print(count_islam2000)
# Out:
# 178

# %% [markdown]
# # 2001

# %%
count_binLanden2001 = 0

for s in sentences2001:
  count_binLanden2001 += s.lower().count('bin laden')

print(count_binLanden2001)
# Out:
# 658

# %%
count_alQaeda2001 = 0

for s in sentences2001:
  count_alQaeda2001 += s.lower().count('al qaeda')

print(count_alQaeda2001)
# Out:
# 273

# %%
count_twinTowers2001 = 0

for s in sentences2001:
  count_twinTowers2001 += s.lower().count('twin towers')

print(count_twinTowers2001)
# Out:
# 41

# %%
count_worldTradeCenter2001 = 0

for s in sentences2001:
  count_worldTradeCenter2001 += s.lower().count('world trade center')

print(count_worldTradeCenter2001)
# Out:
# 405

# %%
count_tower2001 = 0

for s in sentences2001:
  count_tower2001 += s.lower().count('tower')

print(count_tower2001)
# Out:
# 422

# %%
count_attack2001 = 0

for s in sentences2001:
  count_attack2001 += s.lower().count('attack')

print(count_attack2001)
# Out:
# 1619

# %%
count_hijack2001 = 0

for s in sentences2001:
  count_hijack2001 += s.lower().count('hijack')

print(count_hijack2001)
# Out:
# 203

# %%
count_plane2001 = 0

for s in sentences2001:
  count_plane2001 += s.lower().count('plane')

print(count_plane2001)
# Out:
# 1135

# %%
count_terrorism2001 = 0

for s in sentences2001:
  count_terrorism2001 += s.lower().count('terrorism')

print(count_terrorism2001)
# Out:
# 506

# %%
count_afghanistan2001 = 0

for s in sentences2001:
  count_afghanistan2001 += s.lower().count('afghanistan')

print(count_afghanistan2001)
# Out:
# 809

# %%
count_jihad2001 = 0

for s in sentences2001:
  count_jihad2001 += s.lower().count('jihad')

print(count_jihad2001)
# Out:
# 123

# %%
count_islam2001 = 0

for s in sentences2001:
  count_islam2001 += s.lower().count('islam')

print(count_islam2001)
# Out:
# 729

# %% [markdown]
# # 2002

# %%
count_binLanden2002 = 0

for s in sentences2002:
  count_binLanden2002 += s.lower().count('bin laden')

print(count_binLanden2002)
# Out:
# 172

# %%
count_alQaeda2002 = 0

for s in sentences2002:
  count_alQaeda2002 += s.lower().count('al qaeda')

print(count_alQaeda2002)
# Out:
# 291

# %%
count_twinTowers2002 = 0

for s in sentences2002:
  count_twinTowers2002 += s.lower().count('twin towers')

print(count_twinTowers2002)
# Out:
# 35

# %%
count_worldTradeCenter2002 = 0

for s in sentences2002:
  count_worldTradeCenter2002 += s.lower().count('world trade center')

print(count_worldTradeCenter2002)
# Out:
# 214

# %%
count_tower2002 = 0

for s in sentences2002:
  count_tower2002 += s.lower().count('tower')

print(count_tower2002)
# Out:
# 371

# %%
count_attack2002 = 0

for s in sentences2002:
  count_attack2002 += s.lower().count('attack')

print(count_attack2002)
# Out:
# 1413

# %%
count_hijack2002 = 0

for s in sentences2002:
  count_hijack2002 += s.lower().count('hijack')

print(count_hijack2002)
# Out:
# 136

# %%
count_plane2002 = 0

for s in sentences2002:
  count_plane2002 += s.lower().count('plane')

print(count_plane2002)
# Out:
# 586

# %%
count_terrorism2002 = 0

for s in sentences2002:
  count_terrorism2002 += s.lower().count('terrorism')

print(count_terrorism2002)
# Out:
# 522

# %%
count_afghanistan2002 = 0

for s in sentences2002:
  count_afghanistan2002 += s.lower().count('afghanistan')

print(count_afghanistan2002)
# Out:
# 515

# %%
count_jihad2002 = 0

for s in sentences2002:
  count_jihad2002 += s.lower().count('jihad')

print(count_jihad2002)
# Out:
# 80

# %%
count_islam2002 = 0

for s in sentences2002:
  count_islam2002 += s.lower().count('islam')

print(count_islam2002)
# Out:
# 546

# %% [markdown]
# # 2003

# %%
count_binLanden2003 = 0

for s in sentences2003:
  count_binLanden2003 += s.lower().count('bin laden')

print(count_binLanden2003)
# Out:
# 180

# %%
count_alQaeda2003 = 0

for s in sentences2003:
  count_alQaeda2003 += s.lower().count('al qaeda')

print(count_alQaeda2003)
# Out:
# 185

# %%
count_twinTowers2003 = 0

for s in sentences2003:
  count_twinTowers2003 += s.lower().count('twin towers')

print(count_twinTowers2003)
# Out:
# 12

# %%
count_worldTradeCenter2003 = 0

for s in sentences2003:
  count_worldTradeCenter2003 += s.lower().count('world trade center')

print(count_worldTradeCenter2003)
# Out:
# 66

# %%
count_tower2003 = 0

for s in sentences2003:
  count_tower2003 += s.lower().count('tower')

print(count_tower2003)
# Out:
# 264

# %%
count_attack2003 = 0

for s in sentences2003:
  count_attack2003 += s.lower().count('attack')

print(count_attack2003)
# Out:
# 1241

# %%
count_hijack2003 = 0

for s in sentences2003:
  count_hijack2003 += s.lower().count('hijack')

print(count_hijack2003)
# Out:
# 49

# %%
count_plane2003 = 0

for s in sentences2003:
  count_plane2003 += s.lower().count('plane')

print(count_plane2003)
# Out:
# 627

# %%
count_terrorism2003 = 0

for s in sentences2003:
  count_terrorism2003 += s.lower().count('terrorism')

print(count_terrorism2003)
# Out:
# 376

# %%
count_afghanistan2003 = 0

for s in sentences2003:
  count_afghanistan2003 += s.lower().count('afghanistan')

print(count_afghanistan2003)
# Out:
# 274

# %%
count_jihad2003 = 0

for s in sentences2003:
  count_jihad2003 += s.lower().count('jihad')

print(count_jihad2003)
# Out:
# 48

# %%
count_islam2003 = 0

for s in sentences2003:
  count_islam2003 += s.lower().count('islam')

print(count_islam2003)
# Out:
# 358

# %% [markdown]
# # 2004

# %%
count_binLanden2004 = 0

for s in sentences2004:
  count_binLanden2004 += s.lower().count('bin laden')

print(count_binLanden2004)
# Out:
# 184

# %%
count_alQaeda2004 = 0

for s in sentences2004:
  count_alQaeda2004 += s.lower().count('al qaeda')

print(count_alQaeda2004)
# Out:
# 282

# %%
count_twinTowers2004 = 0

for s in sentences2004:
  count_twinTowers2004 += s.lower().count('twin towers')

print(count_twinTowers2004)
# Out:
# 8

# %%
count_worldTradeCenter2004 = 0

for s in sentences2004:
  count_worldTradeCenter2004 += s.lower().count('world trade center')

print(count_worldTradeCenter2004)
# Out:
# 76

# %%
count_tower2004 = 0

for s in sentences2004:
  count_tower2004 += s.lower().count('tower')

print(count_tower2004)
# Out:
# 305

# %%
count_attack2004 = 0

for s in sentences2004:
  count_attack2004 += s.lower().count('attack')

print(count_attack2004)
# Out:
# 1448

# %%
count_hijack2004 = 0

for s in sentences2004:
  count_hijack2004 += s.lower().count('hijack')

print(count_hijack2004)
# Out:
# 134

# %%
count_plane2004 = 0

for s in sentences2004:
  count_plane2004 += s.lower().count('plane')

print(count_plane2004)
# Out:
# 625

# %%
count_terrorism2004 = 0

for s in sentences2004:
  count_terrorism2004 += s.lower().count('terrorism')

print(count_terrorism2004)
# Out:
# 488

# %%
count_afghanistan2004 = 0

for s in sentences2004:
  count_afghanistan2004 += s.lower().count('afghanistan')

print(count_afghanistan2004)
# Out:
# 330

# %%
count_jihad2004 = 0

for s in sentences2004:
  count_jihad2004 += s.lower().count('jihad')

print(count_jihad2004)
# Out:
# 73

# %%
count_islam2004 = 0

for s in sentences2004:
  count_islam2004 += s.lower().count('islam')

print(count_islam2004)
# Out:
# 425

# %% [markdown]
# # 2005

# %%
count_binLanden2005 = 0

for s in sentences2005:
  count_binLanden2005 += s.lower().count('bin laden')

print(count_binLanden2005)
# Out:
# 44

# %%
count_alQaeda2005 = 0

for s in sentences2005:
  count_alQaeda2005 += s.lower().count('al qaeda')

print(count_alQaeda2005)
# Out:
# 92

# %%
count_twinTowers2005 = 0

for s in sentences2005:
  count_twinTowers2005 += s.lower().count('twin towers')

print(count_twinTowers2005)
# Out:
# 11

# %%
count_worldTradeCenter2005 = 0

for s in sentences2005:
  count_worldTradeCenter2005 += s.lower().count('world trade center')

print(count_worldTradeCenter2005)
# Out:
# 33

# %%
count_tower2005 = 0

for s in sentences2005:
  count_tower2005 += s.lower().count('tower')

print(count_tower2005)
# Out:
# 293

# %%
count_attack2005 = 0

for s in sentences2005:
  count_attack2005 += s.lower().count('attack')

print(count_attack2005)
# Out:
# 978

# %%
count_hijack2005 = 0

for s in sentences2005:
  count_hijack2005 += s.lower().count('hijack')

print(count_hijack2005)
# Out:
# 28

# %%
count_plane2005 = 0

for s in sentences2005:
  count_plane2005 += s.lower().count('plane')

print(count_plane2005)
# Out:
# 496

# %%
count_terrorism2005 = 0

for s in sentences2005:
  count_terrorism2005 += s.lower().count('terrorism')

print(count_terrorism2005)
# Out:
# 250

# %%
count_afghanistan2005 = 0

for s in sentences2005:
  count_afghanistan2005 += s.lower().count('afghanistan')

print(count_afghanistan2005)
# Out:
# 199

# %%
count_jihad2005 = 0

for s in sentences2005:
  count_jihad2005 += s.lower().count('jihad')

print(count_jihad2005)
# Out:
# 67

# %%
count_islam2005 = 0

for s in sentences2005:
  count_islam2005 += s.lower().count('islam')

print(count_islam2005)
# Out:
# 517

# %% [markdown]
# # 2006

# %%
count_binLanden2006 = 0

for s in sentences2006:
  count_binLanden2006 += s.lower().count('bin laden')

print(count_binLanden2006)
# Out:
# 87

# %%
count_alQaeda2006 = 0

for s in sentences2006:
  count_alQaeda2006 += s.lower().count('al qaeda')

print(count_alQaeda2006)
# Out:
# 130

# %%
count_twinTowers2006 = 0

for s in sentences2006:
  count_twinTowers2006 += s.lower().count('twin towers')

print(count_twinTowers2006)
# Out:
# 9

# %%
count_worldTradeCenter2006 = 0

for s in sentences2006:
  count_worldTradeCenter2006 += s.lower().count('world trade center')

print(count_worldTradeCenter2006)
# Out:
# 37

# %%
count_tower2006 = 0

for s in sentences2006:
  count_tower2006 += s.lower().count('tower')

print(count_tower2006)
# Out:
# 278

# %%
count_attack2006 = 0

for s in sentences2006:
  count_attack2006 += s.lower().count('attack')

print(count_attack2006)
# Out:
# 1086

# %%
count_hijack2006 = 0

for s in sentences2006:
  count_hijack2006 += s.lower().count('hijack')

print(count_hijack2006)
# Out:
# 26

# %%
count_plane2006 = 0

for s in sentences2006:
  count_plane2006 += s.lower().count('plane')

print(count_plane2006)
# Out:
# 544

# %%
count_terrorism2006 = 0

for s in sentences2006:
  count_terrorism2006 += s.lower().count('terrorism')

print(count_terrorism2006)
# Out:
# 302

# %%
count_afghanistan2006 = 0

for s in sentences2006:
  count_afghanistan2006 += s.lower().count('afghanistan')

print(count_afghanistan2006)
# Out:
# 293

# %%
count_jihad2006 = 0

for s in sentences2006:
  count_jihad2006 += s.lower().count('jihad')

print(count_jihad2006)
# Out:
# 53

# %%
count_islam2006 = 0

for s in sentences2006:
  count_islam2006 += s.lower().count('islam')

print(count_islam2006)
# Out:
# 454

# %% [markdown]
# # 2007

# %%
count_binLanden2007 = 0

for s in sentences2007:
  count_binLanden2007 += s.lower().count('bin laden')

print(count_binLanden2007)
# Out:
# 31

# %%
count_alQaeda2007 = 0

for s in sentences2007:
  count_alQaeda2007 += s.lower().count('al qaeda')

print(count_alQaeda2007)
# Out:
# 144

# %%
count_twinTowers2007 = 0

for s in sentences2007:
  count_twinTowers2007 += s.lower().count('twin towers')

print(count_twinTowers2007)
# Out:
# 8

# %%
count_worldTradeCenter2007 = 0

for s in sentences2007:
  count_worldTradeCenter2007 += s.lower().count('world trade center')

print(count_worldTradeCenter2007)
# Out:
# 11

# %%
count_tower2007 = 0

for s in sentences2007:
  count_tower2007 += s.lower().count('tower')

print(count_tower2007)
# Out:
# 245

# %%
count_attack2007 = 0

for s in sentences2007:
  count_attack2007 += s.lower().count('attack')

print(count_attack2007)
# Out:
# 797

# %%
count_hijack2007 = 0

for s in sentences2007:
  count_hijack2007 += s.lower().count('hijack')

print(count_hijack2007)
# Out:
# 12

# %%
count_plane2007 = 0

for s in sentences2007:
  count_plane2007 += s.lower().count('plane')

print(count_plane2007)
# Out:
# 434

# %%
count_terrorism2007 = 0

for s in sentences2007:
  count_terrorism2007 += s.lower().count('terrorism')

print(count_terrorism2007)
# Out:
# 172

# %%
count_afghanistan2007 = 0

for s in sentences2007:
  count_afghanistan2007 += s.lower().count('afghanistan')

print(count_afghanistan2007)
# Out:
# 164

# %%
count_jihad2007 = 0

for s in sentences2007:
  count_jihad2007 += s.lower().count('jihad')

print(count_jihad2007)
# Out:
# 43

# %%
count_islam2007 = 0

for s in sentences2007:
  count_islam2007 += s.lower().count('islam')

print(count_islam2007)
# Out:
# 424

# %% [markdown]
# # 2008

# %%
count_binLanden2008 = 0

for s in sentences2008:
  count_binLanden2008 += s.lower().count('bin laden')

print(count_binLanden2008)
# Out:
# 40

# %%
count_alQaeda2008 = 0

for s in sentences2008:
  count_alQaeda2008 += s.lower().count('al qaeda')

print(count_alQaeda2008)
# Out:
# 86

# %%
count_twinTowers2008 = 0

for s in sentences2008:
  count_twinTowers2008 += s.lower().count('twin towers')

print(count_twinTowers2008)
# Out:
# 10

# %%
count_worldTradeCenter2008 = 0

for s in sentences2008:
  count_worldTradeCenter2008 += s.lower().count('world trade center')

print(count_worldTradeCenter2008)
# Out:
# 18

# %%
count_tower2008 = 0

for s in sentences2008:
  count_tower2008 += s.lower().count('tower')

print(count_tower2008)
# Out:
# 188

# %%
count_attack2008 = 0

for s in sentences2008:
  count_attack2008 += s.lower().count('attack')

print(count_attack2008)
# Out:
# 806

# %%
count_hijack2008 = 0

for s in sentences2008:
  count_hijack2008 += s.lower().count('hijack')

print(count_hijack2008)
# Out:
# 41

# %%
count_plane2008 = 0

for s in sentences2008:
  count_plane2008 += s.lower().count('plane')

print(count_plane2008)
# Out:
# 473

# %%
count_terrorism2008 = 0

for s in sentences2008:
  count_terrorism2008 += s.lower().count('terrorism')

print(count_terrorism2008)
# Out:
# 146

# %%
count_afghanistan2008 = 0

for s in sentences2008:
  count_afghanistan2008 += s.lower().count('afghanistan')

print(count_afghanistan2008)
# Out:
# 295

# %%
count_jihad2008 = 0

for s in sentences2008:
  count_jihad2008 += s.lower().count('jihad')

print(count_jihad2008)
# Out:
# 77

# %%
count_islam2008 = 0

for s in sentences2008:
  count_islam2008 += s.lower().count('islam')

print(count_islam2008)
# Out:
# 249

# %% [markdown]
# # 2009

# %%
count_binLanden2009 = 0

for s in sentences2009:
  count_binLanden2009 += s.lower().count('bin laden')

print(count_binLanden2009)
# Out:
# 18

# %%
count_alQaeda2009 = 0

for s in sentences2009:
  count_alQaeda2009 += s.lower().count('al qaeda')

print(count_alQaeda2009)
# Out:
# 84

# %%
count_twinTowers2009 = 0

for s in sentences2009:
  count_twinTowers2009 += s.lower().count('twin towers')

print(count_twinTowers2009)
# Out:
# 2

# %%
count_worldTradeCenter2009 = 0

for s in sentences2009:
  count_worldTradeCenter2009 += s.lower().count('world trade center')

print(count_worldTradeCenter2009)
# Out:
# 15

# %%
count_tower2009 = 0

for s in sentences2009:
  count_tower2009 += s.lower().count('tower')

print(count_tower2009)
# Out:
# 212

# %%
count_attack2009 = 0

for s in sentences2009:
  count_attack2009 += s.lower().count('attack')

print(count_attack2009)
# Out:
# 769

# %%
count_hijack2009 = 0

for s in sentences2009:
  count_hijack2009 += s.lower().count('hijack')

print(count_hijack2009)
# Out:
# 38

# %%
count_plane2009 = 0

for s in sentences2009:
  count_plane2009 += s.lower().count('plane')

print(count_plane2009)
# Out:
# 618

# %%
count_terrorism2009 = 0

for s in sentences2009:
  count_terrorism2009 += s.lower().count('terrorism')

print(count_terrorism2009)
# Out:
# 140

# %%
count_afghanistan2009 = 0

for s in sentences2009:
  count_afghanistan2009 += s.lower().count('afghanistan')

print(count_afghanistan2009)
# Out:
# 518

# %%
count_jihad2009 = 0

for s in sentences2009:
  count_jihad2009 += s.lower().count('jihad')

print(count_jihad2009)
# Out:
# 76

# %%
count_islam2009 = 0

for s in sentences2009:
  count_islam2009 += s.lower().count('islam')

print(count_islam2009)
# Out:
# 418

# %% [markdown]
# # 2010

# %%
count_binLanden2010 = 0

for s in sentences2010:
  count_binLanden2010 += s.lower().count('bin laden')

print(count_binLanden2010)
# Out:
# 32

# %%
count_alQaeda2010 = 0

for s in sentences2010:
  count_alQaeda2010 += s.lower().count('al qaeda')

print(count_alQaeda2010)
# Out:
# 59

# %%
count_twinTowers2010 = 0

for s in sentences2010:
  count_twinTowers2010 += s.lower().count('twin towers')

print(count_twinTowers2010)
# Out:
# 1

# %%
count_worldTradeCenter2010 = 0

for s in sentences2010:
  count_worldTradeCenter2010 += s.lower().count('world trade center')

print(count_worldTradeCenter2010)
# Out:
# 18

# %%
count_tower2010 = 0

for s in sentences2010:
  count_tower2010 += s.lower().count('tower')

print(count_tower2010)
# Out:
# 164

# %%
count_attack2010 = 0

for s in sentences2010:
  count_attack2010 += s.lower().count('attack')

print(count_attack2010)
# Out:
# 861

# %%
count_hijack2010 = 0

for s in sentences2010:
  count_hijack2010 += s.lower().count('hijack')

print(count_hijack2010)
# Out:
# 7

# %%
count_plane2010 = 0

for s in sentences2010:
  count_plane2010 += s.lower().count('plane')

print(count_plane2010)
# Out:
# 329

# %%
count_terrorism2010 = 0

for s in sentences2010:
  count_terrorism2010 += s.lower().count('terrorism')

print(count_terrorism2010)
# Out:
# 129

# %%
count_afghanistan2010 = 0

for s in sentences2010:
  count_afghanistan2010 += s.lower().count('afghanistan')

print(count_afghanistan2010)
# Out:
# 503

# %%
count_jihad2010 = 0

for s in sentences2010:
  count_jihad2010 += s.lower().count('jihad')

print(count_jihad2010)
# Out:
# 63

# %%
count_islam2010 = 0

for s in sentences2010:
  count_islam2010 += s.lower().count('islam')

print(count_islam2010)
# Out:
# 332

# %% [markdown]
# # 2011

# %%
count_binLanden2011 = 0

for s in sentences2011:
  count_binLanden2011 += s.lower().count('bin laden')

print(count_binLanden2011)
# Out:
# 128

# %%
count_alQaeda2011 = 0

for s in sentences2011:
  count_alQaeda2011 += s.lower().count('al qaeda')

print(count_alQaeda2011)
# Out:
# 57

# %%
count_twinTowers2011 = 0

for s in sentences2011:
  count_twinTowers2011 += s.lower().count('twin towers')

print(count_twinTowers2011)
# Out:
# 9

# %%
count_worldTradeCenter2011 = 0

for s in sentences2011:
  count_worldTradeCenter2011 += s.lower().count('world trade center')

print(count_worldTradeCenter2011)
# Out:
# 24

# %%
count_tower2011 = 0

for s in sentences2011:
  count_tower2011 += s.lower().count('tower')

print(count_tower2011)
# Out:
# 194

# %%
count_attack2011 = 0

for s in sentences2011:
  count_attack2011 += s.lower().count('attack')

print(count_attack2011)
# Out:
# 943

# %%
count_hijack2011 = 0

for s in sentences2011:
  count_hijack2011 += s.lower().count('hijack')

print(count_hijack2011)
# Out:
# 43

# %%
count_plane2011 = 0

for s in sentences2011:
  count_plane2011 += s.lower().count('plane')

print(count_plane2011)
# Out:
# 507

# %%
count_terrorism2011 = 0

for s in sentences2011:
  count_terrorism2011 += s.lower().count('terrorism')

print(count_terrorism2011)
# Out:
# 136

# %%
count_afghanistan2011 = 0

for s in sentences2011:
  count_afghanistan2011 += s.lower().count('afghanistan')

print(count_afghanistan2011)
# Out:
# 387

# %%
count_jihad2011 = 0

for s in sentences2011:
  count_jihad2011 += s.lower().count('jihad')

print(count_jihad2011)
# Out:
# 33

# %%
count_islam2011 = 0

for s in sentences2011:
  count_islam2011 += s.lower().count('islam')

print(count_islam2011)
# Out:
# 510

# %% [markdown]
# # 2012

# %%
count_binLanden2012 = 0

for s in sentences2012:
  count_binLanden2012 += s.lower().count('bin laden')

print(count_binLanden2012)
# Out:
# 82

# %%
count_alQaeda2012 = 0

for s in sentences2012:
  count_alQaeda2012 += s.lower().count('al qaeda')

print(count_alQaeda2012)
# Out:
# 74

# %%
count_twinTowers2012 = 0

for s in sentences2012:
  count_twinTowers2012 += s.lower().count('twin towers')

print(count_twinTowers2012)
# Out:
# 1

# %%
count_worldTradeCenter2012 = 0

for s in sentences2012:
  count_worldTradeCenter2012 += s.lower().count('world trade center')

print(count_worldTradeCenter2012)
# Out:
# 7

# %%
count_tower2012 = 0

for s in sentences2012:
  count_tower2012 += s.lower().count('tower')

print(count_tower2012)
# Out:
# 193

# %%
count_attack2012 = 0

for s in sentences2012:
  count_attack2012 += s.lower().count('attack')

print(count_attack2012)
# Out:
# 1032

# %%
count_hijack2012 = 0

for s in sentences2012:
  count_hijack2012 += s.lower().count('hijack')

print(count_hijack2012)
# Out:
# 18

# %%
count_plane2012 = 0

for s in sentences2012:
  count_plane2012 += s.lower().count('plane')

print(count_plane2012)
# Out:
# 557

# %%
count_terrorism2012 = 0

for s in sentences2012:
  count_terrorism2012 += s.lower().count('terrorism')

print(count_terrorism2012)
# Out:
# 121

# %%
count_afghanistan2012 = 0

for s in sentences2012:
  count_afghanistan2012 += s.lower().count('afghanistan')

print(count_afghanistan2012)
# Out:
# 540

# %%
count_jihad2012 = 0

for s in sentences2012:
  count_jihad2012 += s.lower().count('jihad')

print(count_jihad2012)
# Out:
# 55

# %%
count_islam2012 = 0

for s in sentences2012:
  count_islam2012 += s.lower().count('islam')

print(count_islam2012)
# Out:
# 478

# %% [markdown]
# # 2013

# %%
count_binLanden2013 = 0

for s in sentences2013:
  count_binLanden2013 += s.lower().count('bin laden')

print(count_binLanden2013)
# Out:
# 40

# %%
count_alQaeda2013 = 0

for s in sentences2013:
  count_alQaeda2013 += s.lower().count('al qaeda')

print(count_alQaeda2013)
# Out:
# 72

# %%
count_twinTowers2013 = 0

for s in sentences2013:
  count_twinTowers2013 += s.lower().count('twin towers')

print(count_twinTowers2013)
# Out:
# 3

# %%
count_worldTradeCenter2013 = 0

for s in sentences2013:
  count_worldTradeCenter2013 += s.lower().count('world trade center')

print(count_worldTradeCenter2013)
# Out:
# 17

# %%
count_tower2013 = 0

for s in sentences2013:
  count_tower2013 += s.lower().count('tower')

print(count_tower2013)
# Out:
# 218

# %%
count_attack2013 = 0

for s in sentences2013:
  count_attack2013 += s.lower().count('attack')

print(count_attack2013)
# Out:
# 830

# %%
count_hijack2013 = 0

for s in sentences2013:
  count_hijack2013 += s.lower().count('hijack')

print(count_hijack2013)
# Out:
# 18

# %%
count_plane2013 = 0

for s in sentences2013:
  count_plane2013 += s.lower().count('plane')

print(count_plane2013)
# Out:
# 528

# %%
count_terrorism2013 = 0

for s in sentences2013:
  count_terrorism2013 += s.lower().count('terrorism')

print(count_terrorism2013)
# Out:
# 111

# %%
count_afghanistan2013 = 0

for s in sentences2013:
  count_afghanistan2013 += s.lower().count('afghanistan')

print(count_afghanistan2013)
# Out:
# 287

# %%
count_jihad2013 = 0

for s in sentences2013:
  count_jihad2013 += s.lower().count('jihad')

print(count_jihad2013)
# Out:
# 60

# %%
count_islam2013 = 0

for s in sentences2013:
  count_islam2013 += s.lower().count('islam')

print(count_islam2013)
# Out:
# 431

# %% [markdown]
# # 2014

# %%
count_binLanden2014 = 0

for s in sentences2014:
  count_binLanden2014 += s.lower().count('bin laden')

print(count_binLanden2014)
# Out:
# 33

# %%
count_alQaeda2014 = 0

for s in sentences2014:
  count_alQaeda2014 += s.lower().count('al qaeda')

print(count_alQaeda2014)
# Out:
# 56

# %%
count_twinTowers2014 = 0

for s in sentences2014:
  count_twinTowers2014 += s.lower().count('twin towers')

print(count_twinTowers2014)
# Out:
# 2

# %%
count_worldTradeCenter2014 = 0

for s in sentences2014:
  count_worldTradeCenter2014 += s.lower().count('world trade center')

print(count_worldTradeCenter2014)
# Out:
# 13

# %%
count_tower2014 = 0

for s in sentences2014:
  count_tower2014 += s.lower().count('tower')

print(count_tower2014)
# Out:
# 173

# %%
count_attack2014 = 0

for s in sentences2014:
  count_attack2014 += s.lower().count('attack')

print(count_attack2014)
# Out:
# 861

# %%
count_hijack2014 = 0

for s in sentences2014:
  count_hijack2014 += s.lower().count('hijack')

print(count_hijack2014)
# Out:
# 19

# %%
count_plane2014 = 0

for s in sentences2014:
  count_plane2014 += s.lower().count('plane')

print(count_plane2014)
# Out:
# 432

# %%
count_terrorism2014 = 0

for s in sentences2014:
  count_terrorism2014 += s.lower().count('terrorism')

print(count_terrorism2014)
# Out:
# 121

# %%
count_afghanistan2014 = 0

for s in sentences2014:
  count_afghanistan2014 += s.lower().count('afghanistan')

print(count_afghanistan2014)
# Out:
# 220

# %%
count_jihad2014 = 0

for s in sentences2014:
  count_jihad2014 += s.lower().count('jihad')

print(count_jihad2014)
# Out:
# 100

# %%
count_islam2014 = 0

for s in sentences2014:
  count_islam2014 += s.lower().count('islam')

print(count_islam2014)
# Out:
# 547

# %% [markdown]
# # 2015

# %%
count_binLanden2015 = 0

for s in sentences2015:
  count_binLanden2015 += s.lower().count('bin laden')

print(count_binLanden2015)
# Out:
# 14

# %%
count_alQaeda2015 = 0

for s in sentences2015:
  count_alQaeda2015 += s.lower().count('al qaeda')

print(count_alQaeda2015)
# Out:
# 55

# %%
count_twinTowers2015 = 0

for s in sentences2015:
  count_twinTowers2015 += s.lower().count('twin towers')

print(count_twinTowers2015)
# Out:
# 5

# %%
count_worldTradeCenter2015 = 0

for s in sentences2015:
  count_worldTradeCenter2015 += s.lower().count('world trade center')

print(count_worldTradeCenter2015)
# Out:
# 10

# %%
count_tower2015 = 0

for s in sentences2015:
  count_tower2015 += s.lower().count('tower')

print(count_tower2015)
# Out:
# 251

# %%
count_attack2015 = 0

for s in sentences2015:
  count_attack2015 += s.lower().count('attack')

print(count_attack2015)
# Out:
# 945

# %%
count_hijack2015 = 0

for s in sentences2015:
  count_hijack2015 += s.lower().count('hijack')

print(count_hijack2015)
# Out:
# 12

# %%
count_plane2015 = 0

for s in sentences2015:
  count_plane2015 += s.lower().count('plane')

print(count_plane2015)
# Out:
# 360

# %%
count_terrorism2015 = 0

for s in sentences2015:
  count_terrorism2015 += s.lower().count('terrorism')

print(count_terrorism2015)
# Out:
# 126

# %%
count_afghanistan2015 = 0

for s in sentences2015:
  count_afghanistan2015 += s.lower().count('afghanistan')

print(count_afghanistan2015)
# Out:
# 152

# %%
count_jihad2015 = 0

for s in sentences2015:
  count_jihad2015 += s.lower().count('jihad')

print(count_jihad2015)
# Out:
# 84

# %%
count_islam2015 = 0

for s in sentences2015:
  count_islam2015 += s.lower().count('islam')

print(count_islam2015)
# Out:
# 562

# %% [markdown]
# # 2016

# %%
count_binLanden2016 = 0

for s in sentences2016:
  count_binLanden2016 += s.lower().count('bin laden')

print(count_binLanden2016)
# Out:
# 23

# %%
count_alQaeda2016 = 0

for s in sentences2016:
  count_alQaeda2016 += s.lower().count('al qaeda')

print(count_alQaeda2016)
# Out:
# 23

# %%
count_twinTowers2016 = 0

for s in sentences2016:
  count_twinTowers2016 += s.lower().count('twin towers')

print(count_twinTowers2016)
# Out:
# 7

# %%
count_worldTradeCenter2016 = 0

for s in sentences2016:
  count_worldTradeCenter2016 += s.lower().count('world trade center')

print(count_worldTradeCenter2016)
# Out:
# 32

# %%
count_tower2016 = 0

for s in sentences2016:
  count_tower2016 += s.lower().count('tower')

print(count_tower2016)
# Out:
# 324

# %%
count_attack2016 = 0

for s in sentences2016:
  count_attack2016 += s.lower().count('attack')

print(count_attack2016)
# Out:
# 1604

# %%
count_hijack2016 = 0

for s in sentences2016:
  count_hijack2016 += s.lower().count('hijack')

print(count_hijack2016)
# Out:
# 30

# %%
count_plane2016 = 0

for s in sentences2016:
  count_plane2016 += s.lower().count('plane')

print(count_plane2016)
# Out:
# 483

# %%
count_terrorism2016 = 0

for s in sentences2016:
  count_terrorism2016 += s.lower().count('terrorism')

print(count_terrorism2016)
# Out:
# 209

# %%
count_afghanistan2016 = 0

for s in sentences2016:
  count_afghanistan2016 += s.lower().count('afghanistan')

print(count_afghanistan2016)
# Out:
# 147

# %%
count_jihad2016 = 0

for s in sentences2016:
  count_jihad2016 += s.lower().count('jihad')

print(count_jihad2016)
# Out:
# 41

# %%
count_islam2016 = 0

for s in sentences2016:
  count_islam2016 += s.lower().count('islam')

print(count_islam2016)
# Out:
# 527

# %% [markdown]
# # 2017

# %%
count_binLanden2017 = 0

for s in sentences2017:
  count_binLanden2017 += s.lower().count('bin laden')

print(count_binLanden2017)
# Out:
# 5

# %%
count_alQaeda2017 = 0

for s in sentences2017:
  count_alQaeda2017 += s.lower().count('al qaeda')

print(count_alQaeda2017)
# Out:
# 17

# %%
count_twinTowers2017 = 0

for s in sentences2017:
  count_twinTowers2017 += s.lower().count('twin towers')

print(count_twinTowers2017)
# Out:
# 2

# %%
count_worldTradeCenter2017 = 0

for s in sentences2017:
  count_worldTradeCenter2017 += s.lower().count('world trade center')

print(count_worldTradeCenter2017)
# Out:
# 11

# %%
count_tower2017 = 0

for s in sentences2017:
  count_tower2017 += s.lower().count('tower')

print(count_tower2017)
# Out:
# 268

# %%
count_attack2017 = 0

for s in sentences2017:
  count_attack2017 += s.lower().count('attack')

print(count_attack2017)
# Out:
# 1334

# %%
count_hijack2017 = 0

for s in sentences2017:
  count_hijack2017 += s.lower().count('hijack')

print(count_hijack2017)
# Out:
# 17

# %%
count_plane2017 = 0

for s in sentences2017:
  count_plane2017 += s.lower().count('plane')

print(count_plane2017)
# Out:
# 458

# %%
count_terrorism2017 = 0

for s in sentences2017:
  count_terrorism2017 += s.lower().count('terrorism')

print(count_terrorism2017)
# Out:
# 154

# %%
count_afghanistan2017 = 0

for s in sentences2017:
  count_afghanistan2017 += s.lower().count('afghanistan')

print(count_afghanistan2017)
# Out:
# 99

# %%
count_jihad2017 = 0

for s in sentences2017:
  count_jihad2017 += s.lower().count('jihad')

print(count_jihad2017)
# Out:
# 30

# %%
count_islam2017 = 0

for s in sentences2017:
  count_islam2017 += s.lower().count('islam')

print(count_islam2017)
# Out:
# 403

# %% [markdown]
# # 2018

# %%
count_binLanden2018 = 0

for s in sentences2018:
  count_binLanden2018 += s.lower().count('bin laden')

print(count_binLanden2018)
# Out:
# 11

# %%
count_alQaeda2018 = 0

for s in sentences2018:
  count_alQaeda2018 += s.lower().count('al qaeda')

print(count_alQaeda2018)
# Out:
# 4

# %%
count_twinTowers2018 = 0

for s in sentences2018:
  count_twinTowers2018 += s.lower().count('twin towers')

print(count_twinTowers2018)
# Out:
# 2

# %%
count_worldTradeCenter2018 = 0

for s in sentences2018:
  count_worldTradeCenter2018 += s.lower().count('world trade center')

print(count_worldTradeCenter2018)
# Out:
# 17

# %%
count_tower2018 = 0

for s in sentences2018:
  count_tower2018 += s.lower().count('tower')

print(count_tower2018)
# Out:
# 294

# %%
count_attack2018 = 0

for s in sentences2018:
  count_attack2018 += s.lower().count('attack')

print(count_attack2018)
# Out:
# 978

# %%
count_hijack2018 = 0

for s in sentences2018:
  count_hijack2018 += s.lower().count('hijack')

print(count_hijack2018)
# Out:
# 19

# %%
count_plane2018 = 0

for s in sentences2018:
  count_plane2018 += s.lower().count('plane')

print(count_plane2018)
# Out:
# 352

# %%
count_terrorism2018 = 0

for s in sentences2018:
  count_terrorism2018 += s.lower().count('terrorism')

print(count_terrorism2018)
# Out:
# 81

# %%
count_afghanistan2018 = 0

for s in sentences2018:
  count_afghanistan2018 += s.lower().count('afghanistan')

print(count_afghanistan2018)
# Out:
# 130

# %%
count_jihad2018 = 0

for s in sentences2018:
  count_jihad2018 += s.lower().count('jihad')

print(count_jihad2018)
# Out:
# 12

# %%
count_islam2018 = 0

for s in sentences2018:
  count_islam2018 += s.lower().count('islam')

print(count_islam2018)
# Out:
# 115

# %% [markdown]
# # 2019

# %%
count_binLanden2019 = 0

for s in sentences2019:
  count_binLanden2019 += s.lower().count('bin laden')

print(count_binLanden2019)
# Out:
# 6

# %%
count_alQaeda2019 = 0

for s in sentences2019:
  count_alQaeda2019 += s.lower().count('al qaeda')

print(count_alQaeda2019)
# Out:
# 5

# %%
count_twinTowers2019 = 0

for s in sentences2019:
  count_twinTowers2019 += s.lower().count('twin towers')

print(count_twinTowers2019)
# Out:
# 2

# %%
count_worldTradeCenter2019 = 0

for s in sentences2019:
  count_worldTradeCenter2019 += s.lower().count('world trade center')

print(count_worldTradeCenter2019)
# Out:
# 6

# %%
count_tower2019 = 0

for s in sentences2019:
  count_tower2019 += s.lower().count('tower')

print(count_tower2019)
# Out:
# 206

# %%
count_attack2019 = 0

for s in sentences2019:
  count_attack2019 += s.lower().count('attack')

print(count_attack2019)
# Out:
# 1242

# %%
count_hijack2019 = 0

for s in sentences2019:
  count_hijack2019 += s.lower().count('hijack')

print(count_hijack2019)
# Out:
# 45

# %%
count_plane2019 = 0

for s in sentences2019:
  count_plane2019 += s.lower().count('plane')

print(count_plane2019)
# Out:
# 458

# %%
count_terrorism2019 = 0

for s in sentences2019:
  count_terrorism2019 += s.lower().count('terrorism')

print(count_terrorism2019)
# Out:
# 87

# %%
count_afghanistan2019 = 0

for s in sentences2019:
  count_afghanistan2019 += s.lower().count('afghanistan')

print(count_afghanistan2019)
# Out:
# 111

# %%
count_jihad2019 = 0

for s in sentences2019:
  count_jihad2019 += s.lower().count('jihad')

print(count_jihad2019)
# Out:
# 17

# %%
count_islam2019 = 0

for s in sentences2019:
  count_islam2019 += s.lower().count('islam')

print(count_islam2019)
# Out:
# 148

# %% [markdown]
# # SUM UP

# %%
count_binLanden = count_binLanden1996 + count_binLanden1997 + count_binLanden1998 + count_binLanden1999 + count_binLanden2000 + count_binLanden2001 + count_binLanden2002 + count_binLanden2003 + count_binLanden2004 + count_binLanden2005 + count_binLanden2006

# %%
count_binLanden
# Out:
# 1399

# %%
count_alQaeda = count_alQaeda1996 + count_alQaeda1997 + count_alQaeda1998 + count_alQaeda1999 + count_alQaeda2000 + count_alQaeda2001 + count_alQaeda2002 + count_alQaeda2003 + count_alQaeda2004 + count_alQaeda2005 + count_alQaeda2006

# %%
count_alQaeda
# Out:
# 1253

# %%
count_twinTowers = count_twinTowers1996 + count_twinTowers1997 + count_twinTowers1998 + count_twinTowers1999 + count_twinTowers2000 + count_twinTowers2001 + count_twinTowers2002 + count_twinTowers2003 + count_twinTowers2004 + count_twinTowers2005 + count_twinTowers2006

# %%
count_twinTowers
# Out:
# 132

# %%
count_worldTradeCenter = count_worldTradeCenter1996 + count_worldTradeCenter1997 + count_worldTradeCenter1998 + count_worldTradeCenter1999 + count_worldTradeCenter2000 + count_worldTradeCenter2001 + count_worldTradeCenter2002 + count_worldTradeCenter2003 + count_worldTradeCenter2004 + count_worldTradeCenter2005 + count_worldTradeCenter2006

# %%
count_worldTradeCenter
# Out:
# 874

# %%
count_tower = count_tower1996 + count_tower1997 + count_tower1998 + count_tower1999 + count_tower2000 + count_tower2001 + count_tower2002 + count_tower2003 + count_tower2004 + count_tower2005 + count_tower2006

# %%
count_tower
# Out:
# 3108

# %%
count_attack = count_attack1996 + count_attack1997 + count_attack1998 + count_attack1999 + count_attack2000 + count_attack2001 + count_attack2002 + count_attack2003 + count_attack2004 + count_attack2005 + count_attack2006

# %%
count_attack
# Out:
# 11013

# %%
count_hijack = count_hijack1996 + count_hijack1997 + count_hijack1998 + count_hijack1999 + count_hijack2000 + count_hijack2001 + count_hijack2002 + count_hijack2003 + count_hijack2004 + count_hijack2005 + count_hijack2006

# %%
count_hijack
# Out:
# 682

# %%
count_plane = count_plane1996 + count_plane1997 + count_plane1998 + count_plane1999 + count_plane2000 + count_plane2001 + count_plane2002 + count_plane2003 + count_plane2004 + count_plane2005 + count_plane2006

# %%
count_plane
# Out:
# 7067

# %%
count_terrorism = count_terrorism1996 + count_terrorism1997 + count_terrorism1998 + count_terrorism1999 + count_terrorism2000 + count_terrorism2001 + count_terrorism2002 + count_terrorism2003 + count_terrorism2004 + count_terrorism2005 + count_terrorism2006

# %%
count_terrorism
# Out:
# 2747

# %%
count_afghanistan = count_afghanistan1996 + count_afghanistan1997 + count_afghanistan1998 + count_afghanistan1999 + count_afghanistan2000 + count_afghanistan2001 + count_afghanistan2002 + count_afghanistan2003 + count_afghanistan2004 + count_afghanistan2005 + count_afghanistan2006

# %%
count_afghanistan
# Out:
# 2594

# %%
count_jihad = count_jihad1996 + count_jihad1997 + count_jihad1998 + count_jihad1999 + count_jihad2000 + count_jihad2001 + count_jihad2002 + count_jihad2003 + count_jihad2004 + count_jihad2005 + count_jihad2006

# %%
count_jihad
# Out:
# 494

# %%
count_islam = count_islam1996 + count_islam1997 + count_islam1998 + count_islam1999 + count_islam2000 + count_islam2001 + count_islam2002 + count_islam2003 + count_islam2004 + count_islam2005 + count_islam2006

# %%
count_islam
# Out:
# 3846

# %% [markdown]
# # GRAPH

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
plt.subplots(figsize=(18,5))
plt.title("Bin Laden")
# Make a random dataset:
height = [count_binLanden1996 , count_binLanden1997 , count_binLanden1998 , count_binLanden1999 , count_binLanden2000 , count_binLanden2001 , count_binLanden2002 , count_binLanden2003 , count_binLanden2004 , count_binLanden2005 , count_binLanden2006, count_binLanden2007, count_binLanden2008, count_binLanden2009, count_binLanden2010, count_binLanden2011, count_binLanden2012, count_binLanden2013, count_binLanden2014, count_binLanden2015, count_binLanden2016 , count_binLanden2017 , count_binLanden2018 , count_binLanden2019]
bars = ('1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height, color="orange")

# Create names on the x-axis
plt.xticks(y_pos, bars)



# Show graphic
plt.show()

# %%
plt.subplots(figsize=(18,5))
plt.title("Al Qaeda")
height = [count_alQaeda1996 , count_alQaeda1997 , count_alQaeda1998 , count_alQaeda1999 , count_alQaeda2000 , count_alQaeda2001 , count_alQaeda2002 , count_alQaeda2003 , count_alQaeda2004 , count_alQaeda2005 , count_alQaeda2006, count_alQaeda2007, count_alQaeda2008, count_alQaeda2009, count_alQaeda2010, count_alQaeda2011, count_alQaeda2012, count_alQaeda2013, count_alQaeda2014, count_alQaeda2015, count_alQaeda2016 , count_alQaeda2017 , count_alQaeda2018 , count_alQaeda2019]
bars = ('1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height, color="orange")

# Create names on the x-axis
plt.xticks(y_pos, bars)

# Show graphic
plt.show()

# %%
plt.subplots(figsize=(18,5))
plt.title("Twins Towers")
height = [count_twinTowers1996 , count_twinTowers1997 , count_twinTowers1998 , count_twinTowers1999 , count_twinTowers2000 , count_twinTowers2001 , count_twinTowers2002 , count_twinTowers2003 , count_twinTowers2004 , count_twinTowers2005 , count_twinTowers2006, count_twinTowers2007, count_twinTowers2008, count_twinTowers2009, count_twinTowers2010, count_twinTowers2011, count_twinTowers2012, count_twinTowers2013, count_twinTowers2014, count_twinTowers2015, count_twinTowers2016 , count_twinTowers2017 , count_twinTowers2018 , count_twinTowers2019]
bars = ('1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height, color="orange")

# Create names on the x-axis
plt.xticks(y_pos, bars)

# Show graphic
plt.show()

# %%
plt.subplots(figsize=(18,5))
plt.title("World Trade Center")
height = [count_worldTradeCenter1996 , count_worldTradeCenter1997 , count_worldTradeCenter1998 , count_worldTradeCenter1999 , count_worldTradeCenter2000 , count_worldTradeCenter2001 , count_worldTradeCenter2002 , count_worldTradeCenter2003 , count_worldTradeCenter2004 , count_worldTradeCenter2005 , count_worldTradeCenter2006, count_worldTradeCenter2007, count_worldTradeCenter2008, count_worldTradeCenter2009, count_worldTradeCenter2010, count_worldTradeCenter2011, count_worldTradeCenter2012, count_worldTradeCenter2013, count_worldTradeCenter2014, count_worldTradeCenter2015, count_worldTradeCenter2016 , count_worldTradeCenter2017 , count_worldTradeCenter2018 , count_worldTradeCenter2019]
bars = ('1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height, color="orange")

# Create names on the x-axis
plt.xticks(y_pos, bars)

# Show graphic
plt.show()

# %%
plt.subplots(figsize=(18,5))
plt.title("Tower")
height = [count_tower1996 , count_tower1997 , count_tower1998 , count_tower1999 , count_tower2000 , count_tower2001 , count_tower2002 , count_tower2003 , count_tower2004 , count_tower2005 , count_tower2006, count_tower2007, count_tower2008, count_tower2009, count_tower2010, count_tower2011, count_tower2012, count_tower2013, count_tower2014, count_tower2015, count_tower2016 , count_tower2017 , count_tower2018 , count_tower2019]
bars = ('1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height, color="orange")

# Create names on the x-axis
plt.xticks(y_pos, bars)

# Show graphic
plt.show()

# %%
plt.subplots(figsize=(18,5))
plt.title("Attack")
height = [count_attack1996 , count_attack1997 , count_attack1998 , count_attack1999 , count_attack2000 , count_attack2001 , count_attack2002 , count_attack2003 , count_attack2004 , count_attack2005 , count_attack2006, count_attack2007, count_attack2008, count_attack2009, count_attack2010, count_attack2011, count_attack2012, count_attack2013, count_attack2014, count_attack2015, count_attack2016 , count_attack2017 , count_attack2018 , count_attack2019]
bars = ('1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height, color="orange")

# Create names on the x-axis
plt.xticks(y_pos, bars)

# Show graphic
plt.show()

# %%
plt.subplots(figsize=(18,5))
plt.title("Hijack")
height = [count_hijack1996 , count_hijack1997 , count_hijack1998 , count_hijack1999 , count_hijack2000 , count_hijack2001 , count_hijack2002 , count_hijack2003 , count_hijack2004 , count_hijack2005 , count_hijack2006, count_hijack2007, count_hijack2008, count_hijack2009, count_hijack2010, count_hijack2011, count_hijack2012, count_hijack2013, count_hijack2014, count_hijack2015, count_hijack2016 , count_hijack2017 , count_hijack2018 , count_hijack2019]
bars = ('1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height, color="orange")

# Create names on the x-axis
plt.xticks(y_pos, bars)

# Show graphic
plt.show()

# %%
plt.subplots(figsize=(18,5))
plt.title("Plane")
height = [count_plane1996 , count_plane1997 , count_plane1998 , count_plane1999 , count_plane2000 , count_plane2001 , count_plane2002 , count_plane2003 , count_plane2004 , count_plane2005 , count_plane2006, count_plane2007, count_plane2008, count_plane2009, count_plane2010, count_plane2011, count_plane2012, count_plane2013, count_plane2014, count_plane2015, count_plane2016 , count_plane2017 , count_plane2018 , count_plane2019]
bars = ('1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height, color="orange")

# Create names on the x-axis
plt.xticks(y_pos, bars)

# Show graphic
plt.show()

# %%
plt.subplots(figsize=(18,5))
plt.title("Terrorism")
height = [count_terrorism1996 , count_terrorism1997 , count_terrorism1998 , count_terrorism1999 , count_terrorism2000 , count_terrorism2001 , count_terrorism2002 , count_terrorism2003 , count_terrorism2004 , count_terrorism2005 , count_terrorism2006, count_terrorism2007, count_terrorism2008, count_terrorism2009, count_terrorism2010, count_terrorism2011, count_terrorism2012, count_terrorism2013, count_terrorism2014, count_terrorism2015, count_terrorism2016 , count_terrorism2017 , count_terrorism2018 , count_terrorism2019]
bars = ('1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height, color="orange")

# Create names on the x-axis
plt.xticks(y_pos, bars)

# Show graphic
plt.show()

# %%
plt.subplots(figsize=(18,5))
plt.title("Afghanistan")
height = [count_afghanistan1996 , count_afghanistan1997 , count_afghanistan1998 , count_afghanistan1999 , count_afghanistan2000 , count_afghanistan2001 , count_afghanistan2002 , count_afghanistan2003 , count_afghanistan2004 , count_afghanistan2005 , count_afghanistan2006, count_afghanistan2007, count_afghanistan2008, count_afghanistan2009, count_afghanistan2010, count_afghanistan2011, count_afghanistan2012, count_afghanistan2013, count_afghanistan2014, count_afghanistan2015, count_afghanistan2016 , count_afghanistan2017 , count_afghanistan2018 , count_afghanistan2019]
bars = ('1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height, color="orange")

# Create names on the x-axis
plt.xticks(y_pos, bars)

# Show graphic
plt.show()

# %%
plt.subplots(figsize=(18,5))
plt.title("Jihad")
height = [count_jihad1996 , count_jihad1997 , count_jihad1998 , count_jihad1999 , count_jihad2000 , count_jihad2001 , count_jihad2002 , count_jihad2003 , count_jihad2004 , count_jihad2005 , count_jihad2006, count_jihad2007, count_jihad2008, count_jihad2009, count_jihad2010, count_jihad2011, count_jihad2012, count_jihad2013, count_jihad2014, count_jihad2015, count_jihad2016 , count_jihad2017 , count_jihad2018 , count_jihad2019]
bars = ('1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height, color="orange")

# Create names on the x-axis
plt.xticks(y_pos, bars)
plt.xlim()
# Show graphic
plt.show()

# %%
plt.subplots(figsize=(18,5))
plt.title("Islam")
height = [count_islam1996 , count_islam1997 , count_islam1998 , count_islam1999 , count_islam2000 , count_islam2001 , count_islam2002 , count_islam2003 , count_islam2004 , count_islam2005 , count_islam2006, count_islam2007, count_islam2008, count_islam2009, count_islam2010, count_islam2011, count_islam2012, count_islam2013, count_islam2014, count_islam2015, count_islam2016 , count_islam2017 , count_islam2018 , count_islam2019]
bars = ('1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height, color="orange")

# Create names on the x-axis
plt.xticks(y_pos, bars)

# Show graphic
plt.show()
